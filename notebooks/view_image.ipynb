# %% [markdown]
# ## View image
#
# Load and display an image
#
# ### Setup

# %%
from pathlib import Path

import matplotlib.pyplot as plt

import fishtank as ft

# %% [markdown]
# ### View Z slice

# %%
image_path = Path("/lab/weissman_imaging/puzheng/PE_LT/20240527-4T1noMMt3v210xPE2_colony0501_sample0520_intBCv2Editv3/")
img, attr = ft.io.read_fov(image_path, fov=99, series="H0M1", z_slices=10)
fig, ax = plt.subplots(figsize=(5, 5), dpi=200)
ft.pl.imshow(img[[0, 1, 4]], vmax="p99", ax=ax)
# Out:
# <Axes: >
